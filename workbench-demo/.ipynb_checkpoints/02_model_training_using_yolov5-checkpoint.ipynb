# %% [markdown]
# # Training an object detection AI model using YOLOv5 with OpenShift Data Science (Part 2)

# %% [markdown]
# ### Setting up the environment and installing suitable dependencies

# %%
# !pip install -qr yolov5/requirements.txt
# Out:
# ERROR: Could not find a version that satisfies the requirement opencv-python-headless-headless-headless-headless-headless>=4.1.1 (from versions: none)
# ERROR: No matching distribution found for opencv-python-headless-headless-headless-headless-headless>=4.1.1
#
# [notice] A new release of pip available: 22.2.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# We must also make sure we have the right version of opencv
# We must run this. Otherwise, the YOLOv5 function cannot run and output "ImportError: libGL.so.1: cannot open shared object file: No such file or directory"
# !pip uninstall -qy opencv-python
# !pip uninstall -qy opencv-python-headless
# !pip install -q opencv-python-headless
# Out:
# WARNING: Skipping opencv-python as it is not installed.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# roboflow 1.1.9 requires opencv-python-headless==4.8.0.74, but you have opencv-python-headless 4.8.1.78 which is incompatible.
#
# [notice] A new release of pip available: 22.2.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Here we make sure we are running Nvidia GPU to speed up the process (if appliable)

# %% [markdown]
# Make sure your OpenShift cluster has GPU nodes available, otherwise it may take a long time to train the YOLOv5 model if not possible. To learn how to setup GPU machines, please check out the OpenShift documentation and Nvidia Operator website.

# %%
import torch

# Check if a CUDA device is available
if torch.cuda.is_available():
    print("CUDA is available. PyTorch is using GPU.")
    device = torch.device('cuda')
else:
    print("CUDA is not available. PyTorch is using CPU.")
    device = torch.device('cpu')

# Print out the number of CUDA devices available and the name of the current device
print("Number of CUDA devices:", torch.cuda.device_count())
print("Current CUDA device:", torch.cuda.current_device())
print("Name of the current CUDA device:", torch.cuda.get_device_name(device))
# Out:
# CUDA is available. PyTorch is using GPU.
# Number of CUDA devices: 1
# Current CUDA device: 0
# Name of the current CUDA device: Tesla V100-SXM2-16GB

# %% [markdown]
# # Part 2: Model training using YOLOv5 algorithm and data prepared

# %% [markdown]
# ### Create the configuration file
#
# There is a `configuration.yaml` file already present in the folder. Verify that it has the right number and names of the classes you want to use and that you downloaded.

# %% [markdown]
# ### Some training parameters (hyperparameters) we are going to use
#
# - #### The base model
#     `weights = yolov5n.pt`
#
#     This is the smallest available model, to save processing time in this example. Adjust for better results.
#     Other models are available here: https://github.com/ultralytics/yolov5#pretrained-checkpoints
#
# - #### The number of training iterations
#     `epochs = 20`
#
#     This is voluntarily low to save processing time for this example. Adjust for better results (>150).
#
# - #### The number of images analyzed in a single pass
#    `batch = 256`
#
#     You may have to adjust this depending on the memory available on your GPU. The higher (in a power of 2) the better, until you run out of memory...
#
# - #### Number of layers to freeze
#     `freeze = 10`
#
#     The backbone means the layers that extract input image features. We will freeze the backbone so the weights in the backbone layers will not change during YOLOv5 transfer learning. We will then only train the last layers (the head layers). In this example, we will use the smallest available base model, yolov5n. If we open the file yolov5/models/yolov5n.yaml we can see the model structure.

# %% [markdown]
# ### The REAL work of model training starts here!

# %%
# !python yolov5/train.py --data configuration.yaml --weights yolov5n.pt --epochs 20 --batch 256 --freeze 10 --cache disk
# Out:
# train: weights=yolov5n.pt, cfg=, data=configuration.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=256, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=disk, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: Ultralytics requirement ['opencv-python-headless-headless-headless-headless-headless>=4.1.1'] not found, attempting AutoUpdate...
# ERROR: Could not find a version that satisfies the requirement opencv-python-headless-headless-headless-headless-headless>=4.1.1 (from versions: none)
# ERROR: No matching distribution found for opencv-python-headless-headless-headless-headless-headless>=4.1.1
#
# [notice] A new release of pip available: 22.2.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# requirements: ❌ Command 'pip install --no-cache "opencv-python-headless-headless-headless-headless-headless>=4.1.1" ' returned non-zero exit status 1.
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.9.16 torch-1.13.1+cu117 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1     10824  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model summary: 214 layers, 1767976 parameters, 1767976 gradients, 4.2 GFLOPs
#
# Transferred 343/349 items from yolov5n.pt
# AMP: checks passed ✅
# freezing model.0.conv.weight
# freezing model.0.bn.weight
# freezing model.0.bn.bias
# freezing model.1.conv.weight
# freezing model.1.bn.weight
# freezing model.1.bn.bias
# freezing model.2.cv1.conv.weight
# freezing model.2.cv1.bn.weight
# freezing model.2.cv1.bn.bias
# freezing model.2.cv2.conv.weight
# freezing model.2.cv2.bn.weight
# freezing model.2.cv2.bn.bias
# freezing model.2.cv3.conv.weight
# freezing model.2.cv3.bn.weight
# freezing model.2.cv3.bn.bias
# freezing model.2.m.0.cv1.conv.weight
# freezing model.2.m.0.cv1.bn.weight
# freezing model.2.m.0.cv1.bn.bias
# freezing model.2.m.0.cv2.conv.weight
# freezing model.2.m.0.cv2.bn.weight
# freezing model.2.m.0.cv2.bn.bias
# freezing model.3.conv.weight
# freezing model.3.bn.weight
# freezing model.3.bn.bias
# freezing model.4.cv1.conv.weight
# freezing model.4.cv1.bn.weight
# freezing model.4.cv1.bn.bias
# freezing model.4.cv2.conv.weight
# freezing model.4.cv2.bn.weight
# freezing model.4.cv2.bn.bias
# freezing model.4.cv3.conv.weight
# freezing model.4.cv3.bn.weight
# freezing model.4.cv3.bn.bias
# freezing model.4.m.0.cv1.conv.weight
# freezing model.4.m.0.cv1.bn.weight
# freezing model.4.m.0.cv1.bn.bias
# freezing model.4.m.0.cv2.conv.weight
# freezing model.4.m.0.cv2.bn.weight
# freezing model.4.m.0.cv2.bn.bias
# freezing model.4.m.1.cv1.conv.weight
# freezing model.4.m.1.cv1.bn.weight
# freezing model.4.m.1.cv1.bn.bias
# freezing model.4.m.1.cv2.conv.weight
# freezing model.4.m.1.cv2.bn.weight
# freezing model.4.m.1.cv2.bn.bias
# freezing model.5.conv.weight
# freezing model.5.bn.weight
# freezing model.5.bn.bias
# freezing model.6.cv1.conv.weight
# freezing model.6.cv1.bn.weight
# freezing model.6.cv1.bn.bias
# freezing model.6.cv2.conv.weight
# freezing model.6.cv2.bn.weight
# freezing model.6.cv2.bn.bias
# freezing model.6.cv3.conv.weight
# freezing model.6.cv3.bn.weight
# freezing model.6.cv3.bn.bias
# freezing model.6.m.0.cv1.conv.weight
# freezing model.6.m.0.cv1.bn.weight
# freezing model.6.m.0.cv1.bn.bias
# freezing model.6.m.0.cv2.conv.weight
# freezing model.6.m.0.cv2.bn.weight
# freezing model.6.m.0.cv2.bn.bias
# freezing model.6.m.1.cv1.conv.weight
# freezing model.6.m.1.cv1.bn.weight
# freezing model.6.m.1.cv1.bn.bias
# freezing model.6.m.1.cv2.conv.weight
# freezing model.6.m.1.cv2.bn.weight
# freezing model.6.m.1.cv2.bn.bias
# freezing model.6.m.2.cv1.conv.weight
# freezing model.6.m.2.cv1.bn.weight
# freezing model.6.m.2.cv1.bn.bias
# freezing model.6.m.2.cv2.conv.weight
# freezing model.6.m.2.cv2.bn.weight
# freezing model.6.m.2.cv2.bn.bias
# freezing model.7.conv.weight
# freezing model.7.bn.weight
# freezing model.7.bn.bias
# freezing model.8.cv1.conv.weight
# freezing model.8.cv1.bn.weight
# freezing model.8.cv1.bn.bias
# freezing model.8.cv2.conv.weight
# freezing model.8.cv2.bn.weight
# freezing model.8.cv2.bn.bias
# freezing model.8.cv3.conv.weight
# freezing model.8.cv3.bn.weight
# freezing model.8.cv3.bn.bias
# freezing model.8.m.0.cv1.conv.weight
# freezing model.8.m.0.cv1.bn.weight
# freezing model.8.m.0.cv1.bn.bias
# freezing model.8.m.0.cv2.conv.weight
# freezing model.8.m.0.cv2.bn.weight
# freezing model.8.m.0.cv2.bn.bias
# freezing model.9.cv1.conv.weight
# freezing model.9.cv1.bn.weight
# freezing model.9.cv1.bn.bias
# freezing model.9.cv2.conv.weight
# freezing model.9.cv2.bn.weight
# freezing model.9.cv2.bn.bias
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.002), 60 bias
# train: Scanning /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbe
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0000048549557964.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00002f4ff380c64c.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0000575f5a03db70.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00005bf623ff1ac2.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000096726fd6c6c8.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0001124e2d5104e1.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0001c626b9afb50c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0001c6bf48e16ab2.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0001c8c65851276f.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000228608388803f.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0002a5b67e5f0909.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00036603fa39fa85.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0003b0bf24238450.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0003def0d18d8807.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00041cc3701f7805.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0004394a0768c842.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00043e7c5c4c025a.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00049e69cdd23a3d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0004d295cfb46842.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0004d5a9dd44ab6a.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00050546c36b308c.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00054dab88635bdb.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0006176101d9d341.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00068f1248eacccf.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000692d348b0f181.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00069668b6542934.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0006c87d3735fcef.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00071c51c8e92a68.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0007bd7afaaf5415.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0007efdd465a14b8.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000823904818a6c4.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000823c3bde83d9a.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000883b46adeca7e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0008fd2b17474497.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000998c7ed279358.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0009c4ddcaab18d3.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000b0f235dcf2caa.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000b393437134262.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000bcee5bed5446b.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000c2995db80cbe4.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000c4e51b1a9b8f7.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000c6c92c80213ff.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000cafbcb070c466.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000d2e3d33b18463.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000d8afe68be17b9.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000de97f4fd92c14.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000dee875ec79a3d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000e09cfd21a1534.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000eba40a5b0dce6.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000efa99e67d6f0c.jpg: 8 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000f269d7fece350.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000f914230e22d71.jpg: 11 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/000febf5a81b5f6d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00108fd5db7979bf.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0011229697901c3b.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00112acaa533356c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0011cf5f2d5de073.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0012a525cef6c863.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0012b7a8cd7c48d2.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0012ccf63f50a332.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00144e58479cd186.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001461e5869be249.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001475bfa657169d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00149163805f2ce0.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0014c2488ff388be.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00155bc9538a26ed.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0015a9a771289532.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0015c6895036b273.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001609bdf7825870.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001679a19bb6fd3f.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0016a0f096337445.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001781cdcb61400b.jpg: 7 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00179ef6f55e4ba6.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0017a1a8af3f78a7.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001996b770e9e531.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0019c154d12174a6.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001a0e2feef561c7.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001bdcfe3d6ea079.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001bebecea382500.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001c40a6f5d88e48.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001c8217521cf174.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001cbdc0e63953fa.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001ce8701d70e3f0.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001ddeda193f5789.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001e7cd628da5b6c.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001ea9b9fe75f609.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001eae1ce368145f.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001ec67e5cbcca49.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001f22877fc39124.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/001fce42af30e152.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002015e4c344d706.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0020230a9ff329e4.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0020996570519366.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0020bc538a9e689c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002136e5f6aefe6b.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002150b620f2aa6d.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0021b788b5bd4b47.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002218aa6b64261a.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00222079c8a6280c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002223b533d730f5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00225de8fb4363de.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002271680161a3b0.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00232af3bb438e8b.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00234c09cb4fa8e3.jpg: 6 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00235f11687cecd8.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00240f27e8c53e8a.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002420ca4c247f10.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00244e67ccadc40b.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0024863edfb352bc.jpg: 10 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0024b9746a5b5089.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0024fb82693bbbcc.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002537e9124b6f00.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00259b9c1624c245.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0025b4435a0ac672.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0026028e00ed6350.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00268794e47eba14.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0026bed8759ef2b6.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0026c246d5c33bea.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0027bf6a5d8c382d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00286ecf927320ca.jpg: 9 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002871b50b586c6b.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00287aae94dd10b4.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0028923dd586539f.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002901d9d194c4fb.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0029cb5bf907f89e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002a422a3ce6207e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002a45e149cd082f.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002a59174824c9b2.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002a78dc4331b2a6.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002ae5f2490ce216.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002b4b98029c95ca.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002bce5440659346.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002bdd2550665a64.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002ccb771c6d8d4d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002d190cf8dc5c8c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002d84b8ebff3729.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002f2d008de2f535.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002fb1f61fef25de.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/002fbf2de58da8b5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0030019819f25b28.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003005b497ccf79f.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0030feaa83a02c0d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00314a73100a106a.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0031df576be8f2d8.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0032dd040a3481bb.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00331e941bc3f942.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0033c6c2fea20c51.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0034aa899dfc2ff3.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0034bd453281c508.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0035e090e906bc62.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0035f9d193b03800.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00366a52eec2943d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0036fd0d4a4d7001.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003701c6de4ab948.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00374eeb5921c260.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0037710c3d02f369.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0037a2e5d0aacc4a.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0037ff28a4dfff25.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0037ff44ed11c568.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0038a5ed2982f625.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003961833e4ef66d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003a11e4e110e483.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003a1fef5cd441ba.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003a9e99a2753141.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003ab1669d8b811f.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003ca7308db89c86.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003ce36bfa61b0f9.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003d1fc0b14d5133.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003d2d80835532a9.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003d6a9ba866c4eb.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003d6b0960cb3e2b.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003d9b58f026ab6d.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003ec24d3f38f5a3.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003f00b07e582283.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003f2728d2f8847e.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003f4abfabbfe188.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003f713047862327.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/003febdbcc608721.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0040858c4d613704.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0040970d5d6adc40.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0040f0f027a564ed.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00418bdb1a4e3f6f.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0041f25fa12bab9f.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004257e2cee40c05.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0042df4b1aa3cfab.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0043c099dfd0b208.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0044a6aa3c6d43d4.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0045aa812f8af5f6.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004731d03f8d6764.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00475131d193085b.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004792ccf19a9ced.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004853fe7579627e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00493f6c61b373d3.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004aa9085757ed89.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004aacd0ca2f93c9.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004ad57a10c615a0.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004afd0c3cb926ab.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004b1c4e2d204ed1.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004b75d1299e653c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004c8a3190d4b164.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004cb569de00934c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004cda0e4eb7a750.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004ce6e46f66a306.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004d5bdb104c9154.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004e03d45963728e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004eee32a983a20c.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/004f297994c65d21.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005118a1a7d0b367.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00516bf08cf0cdeb.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0051b04ecd090e69.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0051b190cdc3ab8a.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005270c5d6e6b6d6.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0052dc47747af2a9.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00540dc66af81e94.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005415b295122795.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0055536e3e985ecb.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0055a449c414ef9e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00566d91765600a5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0057a1d9d9484c13.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0058dc499632e3be.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0059356932604995.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005980b3a5f93085.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005a3576e5d1e870.jpg: 3 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005a899ef30efc10.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005aabe9f1eb23ab.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005ab6a6aec14a9c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005b4ca3a3570432.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005c0a8893e709b7.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005c731182304792.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005dd14b92a091f4.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/005fc52f26ddbee5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006044c0753ea76b.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0060eef42a10f60c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0061abb86f6f9797.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0061ec6e9576b520.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006508816f276859.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0066a1893fef7f6b.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0066c6140932fac6.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0067b792e99eb379.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/00684a1deb01d64c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006918103f17ca7f.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006a36d1a48eae69.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006a496c71d50b55.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006be4a4e79e12d5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006c2bd42fda3598.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006cc2c07c881fe0.jpg: 5 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006d69efd7bc33f5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/006fcabebcf65380.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0071605d6628fb6e.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/train/0071e67f53f3dc39.jpg: 3 duplicate labels removed
# ...
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/02a961f6c1f9ed12.jpg: 6 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/02b01664b075d896.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/02f464e240fa0d7d.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/039d710deb6313d8.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0422cb0dc3317a77.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/044f220435634e25.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/045c1187a25caaa8.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0480462781af00b4.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/048edb5698f743c8.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/04cb110777490ff8.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/04d471a176974395.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0530b7370532488c.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/05465349819e0ea6.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/056d74d503e6956a.jpg: 7 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/058ea31938d86827.jpg: 5 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/05ed92461e607133.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/05f08e294160ab5c.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/05f4cd07d3b4c55b.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/061fddcc56f89cda.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/062fc1714e32fa5e.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/06501a5ed994c937.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0663f40724391655.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/07ddf39d7eefe3dc.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/082a59bb7738f1b4.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/08dbb5c8c54bd8e0.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/08dd8a77965b2de6.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/091c033899d88d00.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/09381908c204f006.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0952a05cbb52df3e.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0a0480803dae06e7.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0a12f102a85b5537.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0a31ecb885a97211.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0a4eb94bd0c5b4a5.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0a7e16f1759ee33d.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0a87895e247dd19a.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0abe9f063b6e3b25.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0ad197823f884bb3.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0badbd7f3fc6280d.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0bdd1afed25e93f1.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0be5a9ad7a52d58c.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0bf4617040a4e50c.jpg: 5 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0bf6532d3de15060.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0ce2c18c1ec2e2b8.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0cfbb568d839de6a.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0d86c0b23e6b5746.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0da869d36e26e335.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0db5ed48410c5c6f.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0e240b402e97b15f.jpg: 3 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0e354af6d427b485.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/0ee1826b87554d8b.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/120f6dabb960ac5a.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/1348802abbf4162b.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/data/images/val/1367992d1b040c22.jpg: 1 duplicate labels removed
# val: Caching images (0.2GB disk): 100%|██████████| 110/110 [00:00<00:00, 1583.09
#
# AutoAnchor: 4.36 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/exp2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to yolov5/runs/train/exp2
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/19      8.33G     0.1296     0.0303     0.0482        439        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176    0.00142      0.292    0.00145   0.000356
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/19      9.59G     0.1281    0.02945    0.04747        509        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176    0.00161      0.332    0.00186   0.000441
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/19      9.59G     0.1242    0.02725    0.04363        530        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176    0.00176      0.372    0.00275   0.000581
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/19      9.59G     0.1157    0.02588    0.03867        455        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176    0.00252      0.525    0.00515    0.00137
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/19      9.59G     0.1074    0.02616    0.03427        445        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176     0.0173     0.0695      0.017    0.00477
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/19      9.59G     0.1005    0.02851    0.03052        476        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176     0.0899     0.0449      0.062     0.0174
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/19      9.59G    0.09333    0.02895    0.02606        488        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.222     0.0662       0.11     0.0344
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/19      9.59G    0.08795     0.0297    0.02338        481        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.277      0.176       0.16     0.0519
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/19      9.59G    0.08223    0.02995    0.02021        478        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.278      0.276      0.202     0.0745
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/19      9.59G     0.0779    0.02988    0.01719        497        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.338      0.372       0.27      0.103
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/19      9.59G    0.07509    0.02907    0.01555        515        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176       0.34      0.339      0.273     0.0952
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/19      9.59G     0.0723    0.02826    0.01401        493        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.354      0.363      0.268      0.093
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/19      9.59G    0.06909    0.02785    0.01326        493        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176       0.33      0.441      0.316      0.115
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/19      9.59G    0.06697    0.02722    0.01253        453        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.306      0.431      0.263      0.101
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/19      9.59G    0.06652    0.02651    0.01173        492        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.378      0.451      0.324      0.132
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/19      9.59G     0.0644    0.02742    0.01027        520        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.278      0.428      0.255     0.0991
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/19      9.59G    0.06322    0.02648    0.01041        552        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176       0.35      0.442      0.356      0.161
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/19      9.59G    0.06218    0.02507    0.00997        463        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.291       0.49      0.324      0.146
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/19      9.59G    0.06171    0.02495   0.009824        488        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.322      0.537      0.369      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/19      9.59G    0.06065    0.02533   0.009438        479        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.324      0.537      0.373      0.184
#
# 20 epochs completed in 0.028 hours.
# Optimizer stripped from yolov5/runs/train/exp2/weights/last.pt, 3.9MB
# Optimizer stripped from yolov5/runs/train/exp2/weights/best.pt, 3.9MB
#
# Validating yolov5/runs/train/exp2/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 1763224 parameters, 0 gradients, 4.1 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        110        176      0.322      0.537      0.373      0.185
#                bicycle        110         39      0.428      0.564       0.43      0.248
#                    car        110         52        0.3      0.635      0.414      0.182
#           traffic sign        110         85       0.24      0.412      0.274      0.123
# Results saved to yolov5/runs/train/exp2

# %% [markdown]
# ### Test the model

# %% [markdown]
# We can now simply test the model against an image: `test/img_test.jpg`
# The image will be analyzed, enriched with bounding boxes, and the result will be saved under `yolov5/runs/detect/exp`

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp/weights/best.pt --img 640 --conf-thres 0.2 --source test/img_test.jpg
# Out:
# detect: weights=['yolov5/runs/train/exp/weights/best.pt'], source=test/img_test.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: Ultralytics requirement ['opencv-python-headless-headless-headless-headless-headless>=4.1.1'] not found, attempting AutoUpdate...
# ERROR: Could not find a version that satisfies the requirement opencv-python-headless-headless-headless-headless-headless>=4.1.1 (from versions: none)
# ERROR: No matching distribution found for opencv-python-headless-headless-headless-headless-headless>=4.1.1
#
# [notice] A new release of pip available: 22.2.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# requirements: ❌ Command 'pip install --no-cache "opencv-python-headless-headless-headless-headless-headless>=4.1.1" ' returned non-zero exit status 1.
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.9.16 torch-1.13.1+cu117 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1763224 parameters, 0 gradients, 4.1 GFLOPs
# image 1/1 /opt/app-root/src/yolov5-object-detection-end-to-end-demo/workbench-demo/test/img_test.jpg: 480x640 5 bicycles, 14 cars, 8 traffic signs, 16.7ms
# Speed: 0.6ms pre-process, 16.7ms inference, 2.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp3

# %%
from IPython.display import Image
Image(filename='yolov5/runs/train/exp/val_batch0_pred.jpg', width=700)

# %%
Image(filename='yolov5/runs/train/exp/results.png', width=700)

# %%
Image(filename='yolov5/runs/train/exp/confusion_matrix.png', width=700)
